# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d681df1da940cea4635a4e57b306c7e9

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 785

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Append the city information into WeatherPy_Database list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 16 | touros
# Processing Record 2 of Set 16 | upernavik
# Processing Record 3 of Set 16 | leningradskiy
# Processing Record 4 of Set 16 | eucaliptus
# Processing Record 5 of Set 16 | ituacu
# Processing Record 6 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 16 | cape town
# Processing Record 8 of Set 16 | russell
# Processing Record 9 of Set 16 | san quintin
# Processing Record 10 of Set 16 | moshenskoye
# Processing Record 11 of Set 16 | hilo
# Processing Record 12 of Set 16 | bagdarin
# Processing Record 13 of Set 16 | mar del plata
# Processing Record 14 of Set 16 | bani walid
# Processing Record 15 of Set 16 | dikson
# Processing Record 16 of Set 16 | rikitea
# Processing Record 17 of Set 16 | mataura
# Processing Record 18 of Set 16 | nemuro
# Processing Record 19 of Set 16 | coihaique
# Processing Record 20 of Set 16 | salalah
# Processing Record 21 of Set 16 | constitucion
# Processing Record 22 of Set 16 | emerald
# Processing Record 23 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 16 | fairbanks
# Processing Record 25 of Set 16 | antofagasta
# Processing Record 26 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 16 | punta arenas
# Processing Record 28 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 16 | ushuaia
# Processing Record 30 of Set 16 | semnan
# Processing Record 31 of Set 16 | ilebo
# Processing Record 32 of Set 16 | zhetysay
# Processing Record 33 of Set 16 | bredasdorp
# Processing Record 34 of Set 16 | hanover
# Processing Record 35 of Set 16 | vaini
# Processing Record 36 of Set 16 | jamestown
# Processing Record 37 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 16 | lorengau
# Processing Record 39 of Set 16 | busselton
# Processing Record 40 of Set 16 | albany
# Processing Record 41 of Set 16 | kapaa
# Processing Record 42 of Set 16 | boquira
# Processing Record 43 of Set 16 | san patricio
# Processing Record 44 of Set 16 | lena
# Processing Record 45 of Set 16 | airai
# Processing Record 46 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 16 | ajaccio
# Processing Record 48 of Set 16 | severo-kurilsk
# Processing Record 49 of Set 16 | yarada
# Processing Record 50 of Set 16 | vila franca do campo
# Processing Record 1 of Set 17 | new norfolk
# Processing Record 2 of Set 17 | banda aceh
# Processing Record 3 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 17 | thompson
# Processing Record 5 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 17 | hithadhoo
# Processing Record 7 of Set 17 | auki
# Processing Record 8 of Set 17 | tarnogskiy gorodok
# Processing Record 9 of Set 17 | andenes
# Processing Record 10 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 17 | baherden
# Processing Record 12 of Set 17 | bambous virieux
# Processing Record 13 of Set 17 | nantucket
# Processing Record 14 of Set 17 | hobart
# Processing Record 15 of Set 17 | alim
# Processing Record 16 of Set 17 | preeceville
# Processing Record 17 of Set 17 | pervomayskiy
# Processing Record 18 of Set 17 | bluff
# Processing Record 19 of Set 17 | geraldton
# Processing Record 20 of Set 17 | laguna
# Processing Record 21 of Set 17 | srednekolymsk
# Processing Record 22 of Set 17 | beruwala
# Processing Record 23 of Set 17 | dhidhdhoo
# Processing Record 24 of Set 17 | cozumel
# Processing Record 25 of Set 17 | kirakira
# Processing Record 26 of Set 17 | hare bay
# Processing Record 27 of Set 17 | ostrovnoy
# Processing Record 28 of Set 17 | pangai
# Processing Record 29 of Set 17 | ilulissat
# Processing Record 30 of Set 17 | khatanga
# Processing Record 31 of Set 17 | atuona
# Processing Record 32 of Set 17 | birao
# Processing Record 33 of Set 17 | swan river
# Processing Record 34 of Set 17 | quatre cocos
# Processing Record 35 of Set 17 | belmonte
# Processing Record 36 of Set 17 | butaritari
# Processing Record 37 of Set 17 | clyde river
# Processing Record 38 of Set 17 | oranjemund
# Processing Record 39 of Set 17 | souillac
# Processing Record 40 of Set 17 | asau
# Processing Record 41 of Set 17 | ouesso
# Processing Record 42 of Set 17 | shenjiamen
# Processing Record 43 of Set 17 | moron
# Processing Record 44 of Set 17 | barrow
# Processing Record 45 of Set 17 | yellowknife
# Processing Record 46 of Set 17 | usinsk
# Processing Record 47 of Set 17 | mount isa
# Processing Record 48 of Set 17 | zhangye
# Processing Record 49 of Set 17 | ihosy
# Processing Record 50 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 18 | qaanaaq
# Processing Record 2 of Set 18 | norman wells
# Processing Record 3 of Set 18 | bereda
# Processing Record 4 of Set 18 | komsomolskiy
# Processing Record 5 of Set 18 | chabahar
# Processing Record 6 of Set 18 | poco verde
# Processing Record 7 of Set 18 | hambantota
# Processing Record 8 of Set 18 | esperance
# Processing Record 9 of Set 18 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 18 | vestmannaeyjar
# Processing Record 11 of Set 18 | cejkovice
# Processing Record 12 of Set 18 | kodiak
# Processing Record 13 of Set 18 | port alfred
# Processing Record 14 of Set 18 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 18 | lizzano
# Processing Record 16 of Set 18 | vardo
# Processing Record 17 of Set 18 | kavieng
# Processing Record 18 of Set 18 | whitehorse
# Processing Record 19 of Set 18 | manaure
# Processing Record 20 of Set 18 | correntina
# Processing Record 21 of Set 18 | klaksvik
# Processing Record 22 of Set 18 | port elizabeth
# Processing Record 23 of Set 18 | flin flon
# Processing Record 24 of Set 18 | kandrian
# Processing Record 25 of Set 18 | muros
# Processing Record 26 of Set 18 | fortuna
# Processing Record 27 of Set 18 | rock springs
# Processing Record 28 of Set 18 | tuktoyaktuk
# Processing Record 29 of Set 18 | kruisfontein
# Processing Record 30 of Set 18 | carlos antonio lopez
# Processing Record 31 of Set 18 | tsogni
# Processing Record 32 of Set 18 | lagoa
# Processing Record 33 of Set 18 | cidreira
# Processing Record 34 of Set 18 | revda
# Processing Record 35 of Set 18 | sechura
# Processing Record 36 of Set 18 | catalao
# Processing Record 37 of Set 18 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 18 | castro
# Processing Record 39 of Set 18 | novovarshavka
# Processing Record 40 of Set 18 | leh
# Processing Record 41 of Set 18 | tessalit
# Processing Record 42 of Set 18 | havre-saint-pierre
# Processing Record 43 of Set 18 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 18 | bacuit
# City not found. Skipping...
# Processing Record 45 of Set 18 | birjand
# Processing Record 46 of Set 18 | jiutai
# Processing Record 47 of Set 18 | myitkyina
# Processing Record 48 of Set 18 | aranos
# Processing Record 49 of Set 18 | torbay
# Processing Record 50 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 19 | canico
# Processing Record 2 of Set 19 | lata
# Processing Record 3 of Set 19 | mumford
# Processing Record 4 of Set 19 | puerto ayora
# Processing Record 5 of Set 19 | nikolskoye
# Processing Record 6 of Set 19 | ribeira grande
# Processing Record 7 of Set 19 | carnarvon
# Processing Record 8 of Set 19 | portland
# Processing Record 9 of Set 19 | san carlos de bariloche
# Processing Record 10 of Set 19 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 11 of Set 19 | arraial do cabo
# Processing Record 12 of Set 19 | ulaangom
# Processing Record 13 of Set 19 | camacari
# Processing Record 14 of Set 19 | ifakara
# Processing Record 15 of Set 19 | baruun-urt
# Processing Record 16 of Set 19 | kushiro
# Processing Record 17 of Set 19 | magadan
# Processing Record 18 of Set 19 | brookhaven
# Processing Record 19 of Set 19 | broken hill
# Processing Record 20 of Set 19 | verkhoyansk
# Processing Record 21 of Set 19 | rosarito
# Processing Record 22 of Set 19 | shimanovsk
# Processing Record 23 of Set 19 | najran
# Processing Record 24 of Set 19 | grand gaube
# Processing Record 25 of Set 19 | half moon bay
# Processing Record 26 of Set 19 | abu samrah
# Processing Record 27 of Set 19 | coquimbo
# Processing Record 28 of Set 19 | soe
# Processing Record 29 of Set 19 | avarua
# Processing Record 30 of Set 19 | gravdal
# Processing Record 31 of Set 19 | neryungri
# Processing Record 32 of Set 19 | vologda
# Processing Record 33 of Set 19 | merke
# Processing Record 34 of Set 19 | neiafu
# Processing Record 35 of Set 19 | oskarshamn
# Processing Record 36 of Set 19 | camacupa
# Processing Record 37 of Set 19 | kaputa
# Processing Record 38 of Set 19 | saint-philippe
# Processing Record 39 of Set 19 | padang
# Processing Record 40 of Set 19 | andevoranto
# City not found. Skipping...
# Processing Record 41 of Set 19 | flinders
# Processing Record 42 of Set 19 | sarangani
# Processing Record 43 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 19 | alto araguaia
# Processing Record 45 of Set 19 | khvorostyanka
# Processing Record 46 of Set 19 | pitimbu
# Processing Record 47 of Set 19 | bengkulu
# Processing Record 48 of Set 19 | marathon
# Processing Record 49 of Set 19 | hobyo
# Processing Record 50 of Set 19 | riyadh
# Processing Record 1 of Set 20 | vaitape
# Processing Record 2 of Set 20 | thinadhoo
# Processing Record 3 of Set 20 | bethel
# Processing Record 4 of Set 20 | sekondi
# Processing Record 5 of Set 20 | faya
# Processing Record 6 of Set 20 | morehead
# Processing Record 7 of Set 20 | iqaluit
# Processing Record 8 of Set 20 | hermanus
# Processing Record 9 of Set 20 | uvira
# Processing Record 10 of Set 20 | tilichiki
# Processing Record 11 of Set 20 | mfou
# Processing Record 12 of Set 20 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 20 | harper
# Processing Record 14 of Set 20 | beaverlodge
# Processing Record 15 of Set 20 | gunnedah
# Processing Record 16 of Set 20 | shingu
# Processing Record 17 of Set 20 | abha
# Processing Record 18 of Set 20 | sitka
# Processing Record 19 of Set 20 | provideniya
# Processing Record 20 of Set 20 | maniitsoq
# Processing Record 21 of Set 20 | rawlins
# Processing Record 22 of Set 20 | nanortalik
# Processing Record 23 of Set 20 | mahebourg
# Processing Record 24 of Set 20 | rognan
# Processing Record 25 of Set 20 | aykhal
# Processing Record 26 of Set 20 | te anau
# Processing Record 27 of Set 20 | san jeronimo
# Processing Record 28 of Set 20 | georgetown
# Processing Record 29 of Set 20 | benemerito de las americas
# Processing Record 30 of Set 20 | szecseny
# Processing Record 31 of Set 20 | eureka
# Processing Record 32 of Set 20 | pastavy
# Processing Record 33 of Set 20 | puerto suarez
# Processing Record 34 of Set 20 | taltal
# Processing Record 35 of Set 20 | pevek
# Processing Record 36 of Set 20 | safranbolu
# Processing Record 37 of Set 20 | buala
# Processing Record 38 of Set 20 | yar-sale
# Processing Record 39 of Set 20 | victoria
# Processing Record 40 of Set 20 | la ronge
# Processing Record 41 of Set 20 | narsaq
# Processing Record 42 of Set 20 | plettenberg bay
# Processing Record 43 of Set 20 | cap malheureux
# Processing Record 44 of Set 20 | mutis
# Processing Record 45 of Set 20 | tasiilaq
# Processing Record 46 of Set 20 | vanavara
# Processing Record 47 of Set 20 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 20 | deputatskiy
# Processing Record 49 of Set 20 | buraydah
# Processing Record 50 of Set 20 | lavrentiya
# Processing Record 1 of Set 21 | zhob
# Processing Record 2 of Set 21 | umm lajj
# Processing Record 3 of Set 21 | mogadishu
# Processing Record 4 of Set 21 | sambava
# Processing Record 5 of Set 21 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 21 | bodden town
# Processing Record 7 of Set 21 | palora
# Processing Record 8 of Set 21 | pesaro
# Processing Record 9 of Set 21 | faanui
# Processing Record 10 of Set 21 | weihe
# Processing Record 11 of Set 21 | thunder bay
# Processing Record 12 of Set 21 | longyearbyen
# Processing Record 13 of Set 21 | olinda
# Processing Record 14 of Set 21 | chokurdakh
# Processing Record 15 of Set 21 | montijo
# Processing Record 16 of Set 21 | tiksi
# Processing Record 17 of Set 21 | sattahip
# Processing Record 18 of Set 21 | saint george
# Processing Record 19 of Set 21 | burnie
# Processing Record 20 of Set 21 | rock sound
# Processing Record 21 of Set 21 | vestmanna
# Processing Record 22 of Set 21 | ambanja
# Processing Record 23 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 21 | batemans bay
# Processing Record 25 of Set 21 | kaitangata
# Processing Record 26 of Set 21 | santa maria
# Processing Record 27 of Set 21 | hattiesburg
# Processing Record 28 of Set 21 | odweyne
# Processing Record 29 of Set 21 | imbituba
# Processing Record 30 of Set 21 | seoul
# Processing Record 31 of Set 21 | zaria
# Processing Record 32 of Set 21 | tecoanapa
# Processing Record 33 of Set 21 | praia da vitoria
# Processing Record 34 of Set 21 | kenai
# Processing Record 35 of Set 21 | kemijarvi
# Processing Record 36 of Set 21 | atka
# City not found. Skipping...
# Processing Record 37 of Set 21 | ornskoldsvik
# Processing Record 38 of Set 21 | chumikan
# Processing Record 39 of Set 21 | padilla
# Processing Record 40 of Set 21 | linchuan
# City not found. Skipping...
# Processing Record 41 of Set 21 | sabang
# Processing Record 42 of Set 21 | cherskiy
# Processing Record 43 of Set 21 | kavaratti
# Processing Record 44 of Set 21 | pacific grove
# Processing Record 45 of Set 21 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 21 | sassandra
# Processing Record 47 of Set 21 | homer
# Processing Record 48 of Set 21 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 21 | puerto baquerizo moreno
# Processing Record 50 of Set 21 | bunia
# Processing Record 1 of Set 22 | cayenne
# Processing Record 2 of Set 22 | grakhovo
# Processing Record 3 of Set 22 | kahului
# Processing Record 4 of Set 22 | tukrah
# Processing Record 5 of Set 22 | davila
# Processing Record 6 of Set 22 | tigil
# Processing Record 7 of Set 22 | trincomalee
# Processing Record 8 of Set 22 | bacong
# Processing Record 9 of Set 22 | port hedland
# Processing Record 10 of Set 22 | omboue
# Processing Record 11 of Set 22 | patiya
# Processing Record 12 of Set 22 | lompoc
# Processing Record 13 of Set 22 | pimentel
# Processing Record 14 of Set 22 | lebu
# Processing Record 15 of Set 22 | hamilton
# Processing Record 16 of Set 22 | kulachi
# Processing Record 17 of Set 22 | garissa
# Processing Record 18 of Set 22 | saldanha
# Processing Record 19 of Set 22 | baykit
# Processing Record 20 of Set 22 | sokoni
# Processing Record 21 of Set 22 | ukiah
# Processing Record 22 of Set 22 | nanchong
# Processing Record 23 of Set 22 | almetyevsk
# Processing Record 24 of Set 22 | camacha
# Processing Record 25 of Set 22 | marzuq
# Processing Record 26 of Set 22 | daxian
# City not found. Skipping...
# Processing Record 27 of Set 22 | karratha
# Processing Record 28 of Set 22 | aldan
# Processing Record 29 of Set 22 | yablonovo
# Processing Record 30 of Set 22 | prince rupert
# Processing Record 31 of Set 22 | lufilufi
# Processing Record 32 of Set 22 | san juan
# Processing Record 33 of Set 22 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 22 | coahuayana
# Processing Record 35 of Set 22 | portsmouth
# Processing Record 36 of Set 22 | kamaishi
# Processing Record 37 of Set 22 | lebanon
# Processing Record 38 of Set 22 | san francisco
# Processing Record 39 of Set 22 | san policarpo
# Processing Record 40 of Set 22 | portalegre
# Processing Record 41 of Set 22 | jalu
# Processing Record 42 of Set 22 | palakkad
# Processing Record 43 of Set 22 | chuy
# Processing Record 44 of Set 22 | gushikawa
# Processing Record 45 of Set 22 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 22 | pingliang
# Processing Record 47 of Set 22 | lasa
# Processing Record 48 of Set 22 | tobol
# Processing Record 49 of Set 22 | olenino
# Processing Record 50 of Set 22 | santa isabel do rio negro
# Processing Record 1 of Set 23 | ambala
# Processing Record 2 of Set 23 | vila velha
# Processing Record 3 of Set 23 | kita
# Processing Record 4 of Set 23 | afrikanda
# Processing Record 5 of Set 23 | arlit
# Processing Record 6 of Set 23 | pangkalanbuun
# Processing Record 7 of Set 23 | ritchie
# Processing Record 8 of Set 23 | hazleton
# Processing Record 9 of Set 23 | amberley
# Processing Record 10 of Set 23 | hay river
# Processing Record 11 of Set 23 | hofn
# Processing Record 12 of Set 23 | maragogi
# Processing Record 13 of Set 23 | ust-nera
# Processing Record 14 of Set 23 | verkhnyaya inta
# Processing Record 15 of Set 23 | torrevieja
# Processing Record 16 of Set 23 | tabas
# Processing Record 17 of Set 23 | warrnambool
# Processing Record 18 of Set 23 | ibi
# Processing Record 19 of Set 23 | mount gambier
# Processing Record 20 of Set 23 | kananga
# Processing Record 21 of Set 23 | katsuura
# Processing Record 22 of Set 23 | elko
# Processing Record 23 of Set 23 | dalby
# Processing Record 24 of Set 23 | sioux lookout
# Processing Record 25 of Set 23 | kieta
# Processing Record 26 of Set 23 | onokhoy
# Processing Record 27 of Set 23 | kutum
# Processing Record 28 of Set 23 | brae
# Processing Record 29 of Set 23 | cheuskiny
# City not found. Skipping...
# Processing Record 30 of Set 23 | gizo
# Processing Record 31 of Set 23 | sao filipe
# Processing Record 32 of Set 23 | erenhot
# Processing Record 33 of Set 23 | cabo san lucas
# Processing Record 34 of Set 23 | kaduqli
# Processing Record 35 of Set 23 | aksarka
# Processing Record 36 of Set 23 | sao miguel do araguaia
# Processing Record 37 of Set 23 | nalut
# Processing Record 38 of Set 23 | kuldiga
# Processing Record 39 of Set 23 | manokwari
# Processing Record 40 of Set 23 | gushi
# Processing Record 41 of Set 23 | yen bai
# Processing Record 42 of Set 23 | bandarbeyla
# Processing Record 43 of Set 23 | freeport
# Processing Record 44 of Set 23 | comodoro rivadavia
# Processing Record 45 of Set 23 | rehoboth
# Processing Record 46 of Set 23 | grindavik
# Processing Record 47 of Set 23 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 23 | hasaki
# Processing Record 49 of Set 23 | ermelo
# Processing Record 50 of Set 23 | santa rita
# Processing Record 1 of Set 24 | ocala
# Processing Record 2 of Set 24 | barroualie
# City not found. Skipping...
# Processing Record 3 of Set 24 | tromso
# Processing Record 4 of Set 24 | domna
# Processing Record 5 of Set 24 | ballina
# Processing Record 6 of Set 24 | necochea
# Processing Record 7 of Set 24 | amapa
# Processing Record 8 of Set 24 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 24 | broome
# Processing Record 10 of Set 24 | horadiz
# Processing Record 11 of Set 24 | fethiye
# Processing Record 12 of Set 24 | vagur
# Processing Record 13 of Set 24 | raudeberg
# Processing Record 14 of Set 24 | kropotkin
# Processing Record 15 of Set 24 | ngunguru
# Processing Record 16 of Set 24 | jishu
# Processing Record 17 of Set 24 | mandalgovi
# Processing Record 18 of Set 24 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 24 | east london
# Processing Record 20 of Set 24 | beringovskiy
# Processing Record 21 of Set 24 | vostok
# Processing Record 22 of Set 24 | juifang
# City not found. Skipping...
# Processing Record 23 of Set 24 | monrovia
# Processing Record 24 of Set 24 | saskylakh
# Processing Record 25 of Set 24 | channel-port aux basques
# Processing Record 26 of Set 24 | husavik
# Processing Record 27 of Set 24 | ambilobe
# Processing Record 28 of Set 24 | san cristobal
# Processing Record 29 of Set 24 | martinsville
# Processing Record 30 of Set 24 | sinnamary
# Processing Record 31 of Set 24 | marawi
# Processing Record 32 of Set 24 | moree
# Processing Record 33 of Set 24 | aguimes
# Processing Record 34 of Set 24 | owando
# Processing Record 35 of Set 24 | kirovskiy
# Processing Record 36 of Set 24 | guerrero negro
# Processing Record 37 of Set 24 | tottori
# Processing Record 38 of Set 24 | kunya
# Processing Record 39 of Set 24 | evensk
# Processing Record 40 of Set 24 | bosaso
# Processing Record 41 of Set 24 | kuchinarai
# Processing Record 42 of Set 24 | isa khel
# Processing Record 43 of Set 24 | goderich
# Processing Record 44 of Set 24 | haines junction
# Processing Record 45 of Set 24 | itoman
# Processing Record 46 of Set 24 | college
# Processing Record 47 of Set 24 | totskoye
# Processing Record 48 of Set 24 | manggar
# Processing Record 49 of Set 24 | jasidih
# Processing Record 50 of Set 24 | babstovo
# Processing Record 1 of Set 25 | buzmeyin
# Processing Record 2 of Set 25 | champerico
# Processing Record 3 of Set 25 | bathsheba
# Processing Record 4 of Set 25 | inongo
# Processing Record 5 of Set 25 | puerto escondido
# Processing Record 6 of Set 25 | bousse
# Processing Record 7 of Set 25 | morondava
# Processing Record 8 of Set 25 | talnakh
# Processing Record 9 of Set 25 | florianopolis
# Processing Record 10 of Set 25 | tenenkou
# Processing Record 11 of Set 25 | methoni
# Processing Record 12 of Set 25 | concepcion
# Processing Record 13 of Set 25 | beisfjord
# Processing Record 14 of Set 25 | beira
# Processing Record 15 of Set 25 | quirinopolis
# Processing Record 16 of Set 25 | san luis
# Processing Record 17 of Set 25 | svetlaya
# Processing Record 18 of Set 25 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 25 | warka
# Processing Record 20 of Set 25 | walvis bay
# Processing Record 21 of Set 25 | selikhino
# Processing Record 22 of Set 25 | high level
# Processing Record 23 of Set 25 | raha
# Processing Record 24 of Set 25 | uyemskiy
# Processing Record 25 of Set 25 | maningrida
# Processing Record 26 of Set 25 | itaueira
# Processing Record 27 of Set 25 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 25 | ibra
# Processing Record 29 of Set 25 | kabanjahe
# Processing Record 30 of Set 25 | bure
# Processing Record 31 of Set 25 | axim
# Processing Record 32 of Set 25 | kulhudhuffushi
# Processing Record 33 of Set 25 | vilyuysk
# Processing Record 34 of Set 25 | nampa
# Processing Record 35 of Set 25 | picayune
# Processing Record 36 of Set 25 | luderitz
# Processing Record 37 of Set 25 | biak
# Processing Record 38 of Set 25 | roald
# Processing Record 39 of Set 25 | ketchikan
# Processing Record 40 of Set 25 | laiagam
# City not found. Skipping...
# Processing Record 41 of Set 25 | sao gabriel
# Processing Record 42 of Set 25 | nicolas bravo
# Processing Record 43 of Set 25 | victor harbor
# Processing Record 44 of Set 25 | suntar
# Processing Record 45 of Set 25 | aklavik
# Processing Record 46 of Set 25 | doha
# Processing Record 47 of Set 25 | zhigansk
# Processing Record 48 of Set 25 | christchurch
# Processing Record 49 of Set 25 | tubruq
# City not found. Skipping...
# Processing Record 50 of Set 25 | phan thiet
# Processing Record 1 of Set 26 | acajutla
# Processing Record 2 of Set 26 | abatskoye
# Processing Record 3 of Set 26 | meulaboh
# Processing Record 4 of Set 26 | alofi
# Processing Record 5 of Set 26 | klyuchi
# Processing Record 6 of Set 26 | cockburn town
# Processing Record 7 of Set 26 | hantsport
# Processing Record 8 of Set 26 | panacan
# Processing Record 9 of Set 26 | bobbili
# Processing Record 10 of Set 26 | borogontsy
# Processing Record 11 of Set 26 | claresholm
# Processing Record 12 of Set 26 | codrington
# Processing Record 13 of Set 26 | namatanai
# Processing Record 14 of Set 26 | banepa
# Processing Record 15 of Set 26 | suluq
# Processing Record 16 of Set 26 | buba
# Processing Record 17 of Set 26 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 26 | khomutovo
# Processing Record 19 of Set 26 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 26 | semey
# Processing Record 21 of Set 26 | abu dhabi
# Processing Record 22 of Set 26 | tibu
# Processing Record 23 of Set 26 | yulara
# Processing Record 24 of Set 26 | gilgit
# Processing Record 25 of Set 26 | hami
# Processing Record 26 of Set 26 | nishihara
# Processing Record 27 of Set 26 | mayo
# Processing Record 28 of Set 26 | the valley
# Processing Record 29 of Set 26 | druskininkai
# Processing Record 30 of Set 26 | oktyabrskoye
# Processing Record 31 of Set 26 | san carlos
# Processing Record 32 of Set 26 | tchollire
# Processing Record 33 of Set 26 | jubayl
# City not found. Skipping...
# Processing Record 34 of Set 26 | antalaha
# Processing Record 35 of Set 26 | pilikwe
# Processing Record 36 of Set 26 | yerbogachen
# Processing Record 37 of Set 26 | mayumba
# Processing Record 38 of Set 26 | praia
# Processing Record 39 of Set 26 | inhambane
# Processing Record 40 of Set 26 | moerai
# Processing Record 41 of Set 26 | hokitika
# Processing Record 42 of Set 26 | plymouth
# Processing Record 43 of Set 26 | cuamba
# Processing Record 44 of Set 26 | yaan
# Processing Record 45 of Set 26 | ourinhos
# Processing Record 46 of Set 26 | mantua
# Processing Record 47 of Set 26 | xingtai
# Processing Record 48 of Set 26 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 26 | aswan
# Processing Record 50 of Set 26 | nakhon thai
# Processing Record 1 of Set 27 | marsa matruh
# Processing Record 2 of Set 27 | keti bandar
# Processing Record 3 of Set 27 | candelaria
# Processing Record 4 of Set 27 | nizwa
# Processing Record 5 of Set 27 | delijan
# Processing Record 6 of Set 27 | parana
# Processing Record 7 of Set 27 | crevalcore
# Processing Record 8 of Set 27 | beloha
# Processing Record 9 of Set 27 | yining
# Processing Record 10 of Set 27 | nadadores
# Processing Record 11 of Set 27 | egvekinot
# Processing Record 12 of Set 27 | chegutu
# Processing Record 13 of Set 27 | noumea
# Processing Record 14 of Set 27 | port augusta
# Processing Record 15 of Set 27 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 27 | tuatapere
# Processing Record 17 of Set 27 | vung tau
# Processing Record 18 of Set 27 | vagay
# Processing Record 19 of Set 27 | port-gentil
# Processing Record 20 of Set 27 | meadow lake
# Processing Record 21 of Set 27 | ierapetra
# Processing Record 22 of Set 27 | mehamn
# Processing Record 23 of Set 27 | fare
# Processing Record 24 of Set 27 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 27 | mbini
# Processing Record 26 of Set 27 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 27 | mbaiki
# Processing Record 28 of Set 27 | araouane
# Processing Record 29 of Set 27 | sayyan
# Processing Record 30 of Set 27 | vao
# Processing Record 31 of Set 27 | avera
# Processing Record 32 of Set 27 | porangatu
# Processing Record 33 of Set 27 | yeppoon
# Processing Record 34 of Set 27 | hervey bay
# Processing Record 35 of Set 27 | les cayes
# Processing Record 36 of Set 27 | nouadhibou
# Processing Record 37 of Set 27 | guaraniacu
# Processing Record 38 of Set 27 | la plata
# Processing Record 39 of Set 27 | varnamo
# Processing Record 40 of Set 27 | malakal
# Processing Record 41 of Set 27 | umm kaddadah
# Processing Record 42 of Set 27 | farah
# Processing Record 43 of Set 27 | ossora
# Processing Record 44 of Set 27 | soyo
# Processing Record 45 of Set 27 | adre
# Processing Record 46 of Set 27 | sabha
# Processing Record 47 of Set 27 | ponta do sol
# Processing Record 48 of Set 27 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 49 of Set 27 | ahipara
# Processing Record 50 of Set 27 | pavlovsk
# Processing Record 1 of Set 28 | iquique
# Processing Record 2 of Set 28 | rioja
# Processing Record 3 of Set 28 | umarkot
# Processing Record 4 of Set 28 | shimoda
# Processing Record 5 of Set 28 | karangampel
# Processing Record 6 of Set 28 | caconda
# Processing Record 7 of Set 28 | luanda
# Processing Record 8 of Set 28 | shchelyayur
# City not found. Skipping...
# Processing Record 9 of Set 28 | presidencia roque saenz pena
# Processing Record 10 of Set 28 | naze
# Processing Record 11 of Set 28 | gat
# Processing Record 12 of Set 28 | tabialan
# City not found. Skipping...
# Processing Record 13 of Set 28 | kijang
# Processing Record 14 of Set 28 | ouagadougou
# Processing Record 15 of Set 28 | ponta pora
# Processing Record 16 of Set 28 | mugan
# Processing Record 17 of Set 28 | hirara
# Processing Record 18 of Set 28 | healdsburg
# Processing Record 19 of Set 28 | dakar
# Processing Record 20 of Set 28 | kysucke nove mesto
# Processing Record 21 of Set 28 | marsh harbour
# Processing Record 22 of Set 28 | arrecife
# Processing Record 23 of Set 28 | tallahassee
# Processing Record 24 of Set 28 | caravelas
# Processing Record 25 of Set 28 | gua musang
# Processing Record 26 of Set 28 | lethem
# Processing Record 27 of Set 28 | paamiut
# Processing Record 28 of Set 28 | palmer
# Processing Record 29 of Set 28 | darhan
# Processing Record 30 of Set 28 | japura
# Processing Record 31 of Set 28 | mporokoso
# Processing Record 32 of Set 28 | sokolo
# Processing Record 33 of Set 28 | kaisiadorys
# Processing Record 34 of Set 28 | songea
# Processing Record 35 of Set 28 | ushibuka
# Processing Record 36 of Set 28 | virginia beach
# Processing Record 37 of Set 28 | connersville
# Processing Record 38 of Set 28 | severnyy
# Processing Record 39 of Set 28 | el reno
# Processing Record 40 of Set 28 | provost
# Processing Record 41 of Set 28 | kota kinabalu
# Processing Record 42 of Set 28 | agadez
# Processing Record 43 of Set 28 | mikuni
# Processing Record 44 of Set 28 | saint-augustin
# Processing Record 45 of Set 28 | sidi ali
# Processing Record 46 of Set 28 | shakawe
# Processing Record 47 of Set 28 | olafsvik
# Processing Record 48 of Set 28 | ikom
# Processing Record 49 of Set 28 | great falls
# Processing Record 50 of Set 28 | richards bay
# Processing Record 1 of Set 29 | rexburg
# Processing Record 2 of Set 29 | awjilah
# Processing Record 3 of Set 29 | assiniboia
# Processing Record 4 of Set 29 | alyangula
# Processing Record 5 of Set 29 | puerto quijarro
# Processing Record 6 of Set 29 | grimstad
# Processing Record 7 of Set 29 | agadir
# Processing Record 8 of Set 29 | jieshi
# Processing Record 9 of Set 29 | bonga
# Processing Record 10 of Set 29 | salmas
# Processing Record 11 of Set 29 | hualmay
# Processing Record 12 of Set 29 | clonakilty
# Processing Record 13 of Set 29 | heihe
# Processing Record 14 of Set 29 | arrifes
# Processing Record 15 of Set 29 | ust-kuyga
# Processing Record 16 of Set 29 | pyapon
# Processing Record 17 of Set 29 | bilibino
# Processing Record 18 of Set 29 | padre bernardo
# Processing Record 19 of Set 29 | vincennes
# Processing Record 20 of Set 29 | ozgon
# City not found. Skipping...
# Processing Record 21 of Set 29 | sovetskiy
# Processing Record 22 of Set 29 | olhao
# Processing Record 23 of Set 29 | gambela
# Processing Record 24 of Set 29 | bialystok
# Processing Record 25 of Set 29 | mbandaka
# Processing Record 26 of Set 29 | contamana
# Processing Record 27 of Set 29 | warragul
# Processing Record 28 of Set 29 | derzhavinsk
# Processing Record 29 of Set 29 | kaele
# Processing Record 30 of Set 29 | devils lake
# Processing Record 31 of Set 29 | mitu
# Processing Record 32 of Set 29 | matamoros
# Processing Record 33 of Set 29 | roma
# Processing Record 34 of Set 29 | tucuman
# Processing Record 35 of Set 29 | rocha
# Processing Record 36 of Set 29 | pisco
# Processing Record 37 of Set 29 | theunissen
# Processing Record 38 of Set 29 | rio gallegos
# Processing Record 39 of Set 29 | rochefort
# Processing Record 40 of Set 29 | voh
# Processing Record 41 of Set 29 | jinji
# Processing Record 42 of Set 29 | aniva
# Processing Record 43 of Set 29 | tome-acu
# City not found. Skipping...
# Processing Record 44 of Set 29 | breves
# Processing Record 45 of Set 29 | boa vista
# Processing Record 46 of Set 29 | havelock
# Processing Record 47 of Set 29 | numan
# Processing Record 48 of Set 29 | buqayq
# City not found. Skipping...
# Processing Record 49 of Set 29 | maumere
# Processing Record 50 of Set 29 | muisne
# Processing Record 1 of Set 30 | mama
# Processing Record 2 of Set 30 | gornopravdinsk
# Processing Record 3 of Set 30 | solnechnyy
# Processing Record 4 of Set 30 | port macquarie
# Processing Record 5 of Set 30 | roblin
# Processing Record 6 of Set 30 | pangnirtung
# Processing Record 7 of Set 30 | mormugao
# Processing Record 8 of Set 30 | cairns
# Processing Record 9 of Set 30 | cabedelo
# Processing Record 10 of Set 30 | jarjis
# City not found. Skipping...
# Processing Record 11 of Set 30 | awbari
# Processing Record 12 of Set 30 | bartica
# Processing Record 13 of Set 30 | khani
# Processing Record 14 of Set 30 | yambio
# Processing Record 15 of Set 30 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 30 | maposeni
# Processing Record 17 of Set 30 | sorong
# Processing Record 18 of Set 30 | los llanos de aridane
# Processing Record 19 of Set 30 | tomatlan
# Processing Record 20 of Set 30 | puerto madero
# Processing Record 21 of Set 30 | qianan
# Processing Record 22 of Set 30 | tazovskiy
# Processing Record 23 of Set 30 | preobrazheniye
# Processing Record 24 of Set 30 | lisala
# Processing Record 25 of Set 30 | mastic beach
# Processing Record 26 of Set 30 | puri
# Processing Record 27 of Set 30 | murray bridge
# Processing Record 28 of Set 30 | labuhan
# Processing Record 29 of Set 30 | luwingu
# Processing Record 30 of Set 30 | urucui
# Processing Record 31 of Set 30 | okakarara
# Processing Record 32 of Set 30 | kupang
# Processing Record 33 of Set 30 | qasigiannguit
# Processing Record 34 of Set 30 | synya
# Processing Record 35 of Set 30 | sidi bu zayd
# City not found. Skipping...
# Processing Record 36 of Set 30 | nabire
# Processing Record 37 of Set 30 | sebinkarahisar
# Processing Record 38 of Set 30 | vidim
# Processing Record 39 of Set 30 | temir
# Processing Record 40 of Set 30 | port hardy
# Processing Record 41 of Set 30 | fuling
# Processing Record 42 of Set 30 | frankfort
# Processing Record 43 of Set 30 | xuanzhou
# Processing Record 44 of Set 30 | mercedes
# Processing Record 45 of Set 30 | north battleford
# Processing Record 46 of Set 30 | whitianga
# Processing Record 47 of Set 30 | dunedin
# Processing Record 48 of Set 30 | lixourion
# Processing Record 49 of Set 30 | shar
# Processing Record 50 of Set 30 | arvika
# Processing Record 1 of Set 31 | banjar
# Processing Record 2 of Set 31 | myanaung
# Processing Record 3 of Set 31 | atar
# Processing Record 4 of Set 31 | mutsu
# Processing Record 5 of Set 31 | simao
# Processing Record 6 of Set 31 | ulladulla
# Processing Record 7 of Set 31 | ixtapa
# Processing Record 8 of Set 31 | camargo
# Processing Record 9 of Set 31 | amurzet
# Processing Record 10 of Set 31 | coulommiers
# Processing Record 11 of Set 31 | devon
# Processing Record 12 of Set 31 | lahij
# Processing Record 13 of Set 31 | sept-iles
# Processing Record 14 of Set 31 | farafangana
# Processing Record 15 of Set 31 | wawa
# Processing Record 16 of Set 31 | maloshuyka
# City not found. Skipping...
# Processing Record 17 of Set 31 | poum
# Processing Record 18 of Set 31 | rancho veloz
# Processing Record 19 of Set 31 | okhotsk
# Processing Record 20 of Set 31 | silver city
# Processing Record 21 of Set 31 | stonewall
# Processing Record 22 of Set 31 | ambon
# Processing Record 23 of Set 31 | reggio di calabria
# Processing Record 24 of Set 31 | antsohihy
# Processing Record 25 of Set 31 | doctor arroyo
# Processing Record 26 of Set 31 | beidao
# Processing Record 27 of Set 31 | urusha
# Processing Record 28 of Set 31 | kastornoye
# Processing Record 29 of Set 31 | lazaro cardenas
# Processing Record 30 of Set 31 | pemangkat
# Processing Record 31 of Set 31 | dolinsk
# Processing Record 32 of Set 31 | humberto de campos
# Processing Record 33 of Set 31 | kansas city
# Processing Record 34 of Set 31 | guangyuan
# Processing Record 35 of Set 31 | santa eulalia del rio
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
WeatherPy_Database = pd.DataFrame(city_data)
WeatherPy_Database.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Touros  -5.20  -35.46     77.00        83          75       10.29
# 1      Upernavik  72.79  -56.15     44.08        71          85       10.58
# 2  Leningradskiy  69.38  178.42     49.05        76           4        4.00
# 3     Eucaliptus -17.58  -67.52     55.33        36           0        8.39
# 4         Ituacu -13.81  -41.30     74.59        58          43        9.95
# 5      Cape Town -33.93   18.42     53.01        93           3        6.93
# 6        Russell  32.35  -85.20     91.40        49           1        6.93
# 7    San Quintin  30.48 -115.95     79.29        66           1        9.48
# 8    Moshenskoye  58.51   34.59     56.14        80          99        5.32
# 9           Hilo  19.73 -155.09     84.20        66          90        6.93
#
#   Country Current Description
# 0      BR       broken clouds
# 1      GL     overcast clouds
# 2      RU           clear sky
# 3      BO           clear sky
# 4      BR    scattered clouds
# 5      ZA           clear sky
# 6      US           clear sky
# 7      MX           clear sky
# 8      RU     overcast clouds
# 9      US     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

WeatherPy_Database = WeatherPy_Database[new_column_order]
WeatherPy_Database.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Touros      BR  -5.20  -35.46     77.00        83          75
# 1      Upernavik      GL  72.79  -56.15     44.08        71          85
# 2  Leningradskiy      RU  69.38  178.42     49.05        76           4
# 3     Eucaliptus      BO -17.58  -67.52     55.33        36           0
# 4         Ituacu      BR -13.81  -41.30     74.59        58          43
# 5      Cape Town      ZA -33.93   18.42     53.01        93           3
# 6        Russell      US  32.35  -85.20     91.40        49           1
# 7    San Quintin      MX  30.48 -115.95     79.29        66           1
# 8    Moshenskoye      RU  58.51   34.59     56.14        80          99
# 9           Hilo      US  19.73 -155.09     84.20        66          90
#
#    Wind Speed Current Description
# 0       10.29       broken clouds
# 1       10.58     overcast clouds
# 2        4.00           clear sky
# 3        8.39           clear sky
# 4        9.95    scattered clouds
# 5        6.93           clear sky
# 6        6.93           clear sky
# 7        9.48           clear sky
# 8        5.32     overcast clouds
# 9        6.93     overcast clouds

# %%
WeatherPy_Database.to_csv("WeatherPy_Database.csv")
